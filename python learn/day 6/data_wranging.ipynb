# %% [markdown]
# # **data wranging**

# %% [markdown]
# data wranging is the a percess of cleaing ,transforming, and oranzine the data,

# %%
#libaries
import pandas as pd
import seaborn as sns
import  matplotlib.pyplot as plt
import  numpy as np

# %% [markdown]
# diff step are use
# 1. gathering the data
# 2. tools to clean data(libaries)
# 3. how to cleans

# %%
df=sns.load_dataset('titanic')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# now asessing the data\
# cleaning start

# %%
df=df.drop(columns='deck')

# %%
df
# Out:
#      survived  pclass     sex   age  ...  adult_male  embark_town  alive  alone
# 0           0       3    male  22.0  ...        True  Southampton     no  False
# 1           1       1  female  38.0  ...       False    Cherbourg    yes  False
# 2           1       3  female  26.0  ...       False  Southampton    yes   True
# 3           1       1  female  35.0  ...       False  Southampton    yes  False
# 4           0       3    male  35.0  ...        True  Southampton     no   True
# ..        ...     ...     ...   ...  ...         ...          ...    ...    ...
# 886         0       2    male  27.0  ...        True  Southampton     no   True
# 887         1       1  female  19.0  ...       False  Southampton    yes   True
# 888         0       3  female   NaN  ...       False  Southampton     no  False
# 889         1       1    male  26.0  ...        True    Cherbourg    yes   True
# 890         0       3    male  32.0  ...        True   Queenstown     no   True
#
# ...

# %%
df['age']=df.age.fillna(df['age'].mean())

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
df.shape
# Out:
# (891, 14)

# %%
df['embarked']=df.embarked.fillna(df['embarked'].mode()[0])

# %%
df['embark_town']=df.embark_town.fillna(df['embark_town'].mode()[0])

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# # outliers removal

# %% [markdown]
# visualization method

# %%
sns.boxplot(df,y='age',hue='who')
# Out:
# <Axes: ylabel='age'>

# %% [markdown]
# **IQR method**

# %%
Q1=df['age'].quantile(0.25)
Q3=df['age'].quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# np.float64(13.0)

# %% [markdown]
# # **important note**

# %%
Q1=df['age'].quantile(0.25)
Q3=df['age'].quantile(0.75)
IQR=Q3-Q1
IQR
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

df=df[(df['age']>lower_bound)&(df['age']<upper_bound)]

# %%
df.shape
# Out:
# (825, 14)

# %%
Q1=df['fare'].quantile(0.25)
Q3=df['fare'].quantile(0.75)
IQR=Q3-Q1
IQR    

lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

df=df[(df['fare']>lower_bound)&(df['fare']<upper_bound)]

# %%
df.shape
# Out:
# (718, 14)

# %%
#zscore
from scipy import stats
import   numpy as np

# %% [markdown]
# # this method will be checked later

# %%
zscore= np.abs(stats.zscore(df['age']))
threshold=3
df=df[[zscore<threshold].all(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[102], line 3
#       1 zscore= np.abs(stats.zscore(df['age']))
#       2 threshold=3
# ----> 3 df=df[[zscore<threshold].all(axis=1)]
#
# AttributeError: 'list' object has no attribute 'all'

# %% [markdown]
# # duplicates how to check

# %%
df.shape
# Out:
# (718, 14)

# %%
#how to find duplicates
df.duplicated().sum()
# Out:
# np.int64(103)

# %%
df_dup=df[df.duplicated()]

# %%
df_dup
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 47          1       3  female  29.699118      0      0   7.7500        Q
# 76          0       3    male  29.699118      0      0   7.8958        S
# 77          0       3    male  29.699118      0      0   8.0500        S
# 87          0       3    male  29.699118      0      0   8.0500        S
# 95          0       3    male  29.699118      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 870         0       3    male  26.000000      0      0   7.8958        S
# 877         0       3    male  19.000000      0      0   7.8958        S
# 878         0       3    male  29.699118      0      0   7.8958        S
# 884         0       3    male  25.000000      0      0   7.0500        S
# 886         0       2    male  27.000000      0      0  13.0000        S
#
#       class    who  adult_male  embark_town alive  alone
# ...

# %%
df_dup.shape
# Out:
# (103, 14)

# %%
#duplicates find and drop
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (615, 14)

# %% [markdown]
# # normalization

# %% [markdown]
# pip install scikit-learn\
# this labry is used for normalization

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

#data
df

#select for column for normalize

cols_to_normalize=['age','fare']

#create the scaler function or tool

scaler=MinMaxScaler()

#fit and transform  the data on scaler or vise verse

df[cols_to_normalize]=scaler.fit_transform(df[cols_to_normalize])

#check the data

df
# Out:
#      survival  pclass     sex       age  ...  embark_town  alive  alone family_size
# 0           0       3    male  0.372549  ...  Southampton     no  False           1
# 2           1       3  female  0.450980  ...  Southampton    yes   True           0
# 3           1       1  female  0.627451  ...  Southampton    yes  False           1
# 4           0       3    male  0.627451  ...  Southampton     no   True           0
# 5           0       3    male  0.523512  ...   Queenstown     no   True           0
# ..        ...     ...     ...       ...  ...          ...    ...    ...         ...
# 885         0       3  female  0.705882  ...   Queenstown     no  False           5
# 887         1       1  female  0.313725  ...  Southampton    yes   True           0
# 888         0       3  female  0.523512  ...  Southampton     no  False           3
# 889         1       1    male  0.450980  ...    Cherbourg    yes   True           0
# ...

# %%
#df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  615.000000  615.000000  615.000000  615.000000  615.000000  615.000000
# mean     0.360976    2.469919    0.497584    0.460163    0.365854    0.298831
# std      0.480674    0.741063    0.209485    0.894039    0.835572    0.221334
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.372549    0.000000    0.000000    0.128640
# 50%      0.000000    3.000000    0.523512    0.000000    0.000000    0.211798
# 75%      1.000000    3.000000    0.607843    1.000000    0.000000    0.423596
# max      1.000000    3.000000    1.000000    5.000000    6.000000    1.000000

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

#data
df

#select for column for normalize

cols_to_normalize=['age','fare']

#create the scaler function or tool

scaler=StandardScaler()

#fit and transform  the data on scaler or vise verse

df[cols_to_normalize]=scaler.fit_transform(df[cols_to_normalize])

#check the data

df
# Out:
#      survived  pclass     sex       age  ...  adult_male  embark_town  alive  alone
# 0           0       3    male -0.597354  ...        True  Southampton     no  False
# 2           1       3  female -0.222648  ...       False  Southampton    yes   True
# 3           1       1  female  0.620441  ...       False  Southampton    yes  False
# 4           0       3    male  0.620441  ...        True  Southampton     no   True
# 5           0       3    male  0.123872  ...        True   Queenstown     no   True
# ..        ...     ...     ...       ...  ...         ...          ...    ...    ...
# 885         0       3  female  0.995147  ...       False   Queenstown     no  False
# 887         1       1  female -0.878384  ...       False  Southampton    yes   True
# 888         0       3  female  0.123872  ...       False  Southampton     no  False
# 889         1       1    male -0.222648  ...        True    Cherbourg    yes   True
# ...

# %%
df.describe()
# Out:
#          survived      pclass  ...       parch          fare
# count  615.000000  615.000000  ...  615.000000  6.150000e+02
# mean     0.360976    2.469919  ...    0.365854  5.776770e-18
# std      0.480674    0.741063  ...    0.835572  1.000814e+00
# min      0.000000    1.000000  ...    0.000000 -1.351236e+00
# 25%      0.000000    2.000000  ...    0.000000 -7.695610e-01
# 50%      0.000000    3.000000  ...    0.000000 -3.935399e-01
# 75%      1.000000    3.000000  ...    0.000000  5.641565e-01
# max      1.000000    3.000000  ...    6.000000  3.170505e+00
#
# [8 rows x 6 columns]

# %%
kasti=sns.load_dataset('titanic')
kasti['age']=kasti['age'].fillna(kasti['age'].median())
kasti['fare']=kasti['fare'].fillna(kasti['fare'].median())

#lod transformation
kasti['age']=np.log(kasti['age'])
kasti['fare']=np.log(kasti['fare'])
kasti.head()
# Out:
# c:\Users\muhammad waseem\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    survived  pclass     sex       age  ...  deck  embark_town  alive  alone
# 0         0       3    male  3.091042  ...   NaN  Southampton     no  False
# 1         1       1  female  3.637586  ...     C    Cherbourg    yes  False
# 2         1       3  female  3.258097  ...   NaN  Southampton    yes   True
# 3         1       1  female  3.555348  ...     C  Southampton    yes  False
# 4         0       3    male  3.555348  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
sns.boxplot(data=kasti,x='age',y='sex')
# Out:
# <Axes: xlabel='age', ylabel='sex'>

# %%
sns.boxplot(data=kasti,x='sex',y='fare')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
df
# Out:
#      survival  pclass     sex       age  ...  embark_town  alive  alone family_size
# 0           0       3    male  0.372549  ...  Southampton     no  False           1
# 2           1       3  female  0.450980  ...  Southampton    yes   True           0
# 3           1       1  female  0.627451  ...  Southampton    yes  False           1
# 4           0       3    male  0.627451  ...  Southampton     no   True           0
# 5           0       3    male  0.523512  ...   Queenstown     no   True           0
# ..        ...     ...     ...       ...  ...          ...    ...    ...         ...
# 885         0       3  female  0.705882  ...   Queenstown     no  False           5
# 887         1       1  female  0.313725  ...  Southampton    yes   True           0
# 888         0       3  female  0.523512  ...  Southampton     no  False           3
# 889         1       1    male  0.450980  ...    Cherbourg    yes   True           0
# ...

# %%
df
# Out:
#      survived  pclass     sex        age  ...  adult_male  embark_town  alive  alone
# 0           0       3    male  22.000000  ...        True  Southampton     no  False
# 2           1       3  female  26.000000  ...       False  Southampton    yes   True
# 3           1       1  female  35.000000  ...       False  Southampton    yes  False
# 4           0       3    male  35.000000  ...        True  Southampton     no   True
# 5           0       3    male  29.699118  ...        True   Queenstown     no   True
# ..        ...     ...     ...        ...  ...         ...          ...    ...    ...
# 885         0       3  female  39.000000  ...       False   Queenstown     no  False
# 887         1       1  female  19.000000  ...       False  Southampton    yes   True
# 888         0       3  female  29.699118  ...       False  Southampton     no  False
# 889         1       1    male  26.000000  ...        True    Cherbourg    yes   True
# ...

# %%
df['family_size']=df['sibsp']+ df['parch']

# %%
sns.swarmplot(data=df,x='sex',y='fare',hue='family_size')
# Out:
# c:\Users\muhammad waseem\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 24.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='sex', ylabel='fare'>
# c:\Users\muhammad waseem\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 31.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\muhammad waseem\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df=df.rename(columns={'survived':'survival'})
df.columns
# Out:
# Index(['survival', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'family_size'],
#       dtype='object')

# %%
#pivat table
table=pd.pivot_table(df,values='fare',index='pclass',
                     columns='survival',aggfunc=np.sum)
table
# Out:
# C:\Users\muhammad waseem\AppData\Local\Temp\ipykernel_7708\879878178.py:2: FutureWarning: The provided callable <function sum at 0x000001755F262520> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table=pd.pivot_table(df,values='fare',index='pclass',
# survival          0          1
# pclass
# 1         22.070517  35.036780
# 2         20.685278  24.594516
# 3         60.609425  20.784525

# %%
df.to_csv('preprocessing_data.csv')
