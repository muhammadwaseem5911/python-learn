# %%
import seaborn as sns
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", col="region",
    hue="event", style="event",
)

# %%
tips=sns.load_dataset('tips')
sns.lmplot(data=tips, x="total_bill", y="tip", col="time", hue="smoker")

# %% [markdown]
# # dis plot mean distibution plot
# ## in this plot if you use col mean other column give a best rest

# %%
sns.displot(data=tips, x="total_bill", col="time", kde=True)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # in this plot kind is used swam this is also type of catplot

# %%
sns.catplot(data=tips, kind="swarm", x="day", y="total_bill", hue="smoker")

# %% [markdown]
# # cat plot in which also kind is used violin

# %%
sns.catplot(data=tips, kind="violin", x="day", y="total_bill", hue="smoker", split=True)

# %% [markdown]
# # joint plot

# %%
penguins = sns.load_dataset("penguins")
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %% [markdown]
# this is the beautiful plot and in this diff plot are used  to show the difference between the two plots

# %%
g = sns.PairGrid(penguins, hue="species", corner=True)
g.map_lower(sns.kdeplot, hue=None, levels=5, color=".2")
g.map_lower(sns.scatterplot, marker="+")
g.map_diag(sns.histplot, element="step", linewidth=0, kde=True)
g.add_legend(frameon=True)
g.legend.set_bbox_to_anchor((.61, .6))

# %% [markdown]
# relplot mean relationplotand this graph shows theme function

# %%
sns.set_theme(style="ticks", font_scale=1.25)
g = sns.relplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm", hue="body_mass_g",
    palette="crest", marker="x", s=100,
)
g.set_axis_labels("Bill length (mm)", "Bill depth (mm)", labelpad=10)
g.legend.set_title("Body mass (g)")
g.figure.set_size_inches(6.5, 4.5)
g.ax.margins(.15)
g.despine(trim=True)

# %% [markdown]
# ### only here multiple function is used for making the plot and also kdeplot is a type of plot
# which also type of distribution data

# %%
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %% [markdown]
# ## this method use for name the labels
# ### set axis_labels(and then give the names)

# %%
g = sns.relplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", col="sex")
g.set_axis_labels("Flipper length (mm)", "Bill length (mm)")
